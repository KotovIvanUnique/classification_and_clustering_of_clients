# %%
import sys
import pandas as pd
import logging, datetime, os
from sklearn.cluster import KMeans
import warnings
from sklearn import preprocessing
from xgboost import XGBClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedShuffleSplit, StratifiedKFold
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#%config Application.log_level="INFO"
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
warnings.simplefilter('ignore')

# %% [markdown]
# ## Файлы

# %%
# клиенты с одним продуктом (выгрузка из базы)
#file_name = 'clients_clustering.csv'

file_name = 'INSURE_TEXT_MINING/data_insure_2018.csv'

# клиенты с несколькими продуктами (результат классификации платежек)
#file_name = 'multiproduct_clients_clustering.csv'

# клиенты с одним продуктом (результат классификации платежек)
#file_name = 'one_product_clients_clustering.csv'

# %% [markdown]
# ## Формирование исходных данных с суммами

# %%
# Инициализация исходных даных:
    
data = pd.read_csv(file_name, encoding='cp1251', delimiter=';')
data = data.rename(columns = {"PREDICTED" : "CLASS"})
data = data.dropna(subset=['CLASS'])

# Список продуктов

labels = sorted(list(data['CLASS'].drop_duplicates()))

# Формируем данные для кластеризации (ИНН и колечество платежей по продуктам)

data['COUNT'] = 1
data['SUMMA'] = pd.to_numeric(data['SUMMA'].apply(lambda x: x.replace(',','.')))
data['SUMMA_MEAN'] = data['SUMMA']
data['SUMMA_STD'] = data['SUMMA']

data_pivot = pd.pivot_table(data,
               values=[
                        'SUMMA',
                        'SUMMA_MEAN',                       
                        'SUMMA_STD',                       
                        'COUNT',
                      ],
               index = ['INN','CLASS'],
               aggfunc={
                   'SUMMA' : np.sum,
                   'SUMMA_MEAN' : np.mean,
                   'SUMMA_STD' : np.std,
                   'COUNT' : np.sum,
               }).unstack().fillna(0)
data_pivot['INN'] = data_pivot.index

# Загружаем размеченных клиентов

file_2_name = 'inn_product.csv'

data_label = pd.read_csv(file_2_name, encoding='cp1251', delimiter=';')
data_label = data_label.drop_duplicates()
data_label = data_label.rename(columns = {"PARTICIPANT_INN" : "INN"})

# Витрина по всем клиентам (ИНН и количество платежей по продуктам и класс клиента)

data_merged = pd.merge(data_pivot,data_label,on='INN')

# Витрина по клиентам, имеющим только один продукт (ИНН и количество платежей по продуктам и класс клиента)

data_label_counts = data_label.groupby('INN',as_index = False).count()
inn_with_1_product = pd.DataFrame(data_label_counts[data_label_counts['CLASS']  == 1]['INN'].drop_duplicates())
data_label_inn_with_1_product = pd.merge(data_label,inn_with_1_product,on='INN')

data_merged_inn_with_1_product = pd.merge(data_pivot,data_label_inn_with_1_product,on='INN')

labels_for_training = [x for x in list(data_merged_inn_with_1_product.columns) if 'INN' not in x and 'CLASS' not in x]

# Нормализуем численные значения

data_values = data_merged_inn_with_1_product[labels_for_training].values
scaler = preprocessing.Normalizer()
standardscaler = preprocessing.StandardScaler()
data_merged_inn_with_1_product[labels_for_training] = standardscaler.fit_transform(scaler.fit_transform(data_values))

# %% [markdown]
# ## Для клиентов с одним продуктом

# %%
X_train1,X_test1,y_train1,y_test1 = train_test_split(data_merged_inn_with_1_product[labels_for_training],
                                                     data_merged_inn_with_1_product['CLASS'],
                                                     test_size = 0.2,
                                                     random_state = 40
                                                     )
text_clf_xgb = XGBClassifier()
text_clf_xgb = text_clf_xgb.fit(X_train1,y_train1)
predicted_values_xgb = text_clf_xgb.predict(X_test1)
print(metrics.classification_report(y_test1,
                                    predicted_values_xgb,
                                    target_names = data_merged_inn_with_1_product['CLASS'].unique()))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                                Питание       1.00      0.95      0.98        22
#                                 Строительные материалы       1.00      1.00      1.00        24
#                                                 Ремонт       1.00      0.67      0.80         3
#                                            Медицинский       1.00      0.67      0.80         3
#                                                 Охрана       0.95      0.97      0.96        62
#                                                    ГСМ       1.00      0.88      0.93        16
#                                          Хозяйственный       0.67      0.50      0.57         4
# Оказание услуг по проведению лабораторных исследований       1.00      0.80      0.89         5
#                                             Автомобили       0.97      0.95      0.96        60
#                                                 Одежда       0.67      1.00      0.80         2
#                                                 Мебель       0.88      1.00      0.94        15
#                                   Оценка условий труда       0.93      1.00      0.97        14
#                                             Сантехника       1.00      1.00      1.00        11
#                                             Оргтехника       0.94      1.00      0.97        17
#                                     Печатная продукция       0.95      1.00      0.97        19
#                                           Автозапчасти       1.00      1.00      1.00         5
#                                          Электротовары       0.95      0.99      0.97        81
#                                            Страхование       1.00      1.00      1.00         4
#                                           Канцелярский       1.00      0.86      0.92         7
#                                          Бытовая химия       1.00      1.00      1.00         3
#                                        Бытовая техника       0.95      0.91      0.93        22
#                                       Финансовый аудит       1.00      0.50      0.67         2
#                              Компьютерное оборудование       0.79      0.79      0.79        19
#                                           Оборудование       0.83      0.91      0.87        11
#
#                                            avg / total       0.95      0.95      0.95       431

# %% [markdown]
# ## Для клиентов с несколькими продуктами

# %%
X_train,X_test,y_train,y_test = train_test_split(data_merged[labels_for_training],
                                                 data_merged['CLASS'],
                                                 test_size = 0.2,
                                                 random_state = 40)
text_clf_xgb = XGBClassifier()
text_clf_xgb = text_clf_xgb.fit(X_train,y_train)
predicted_values_xgb = text_clf_xgb.predict(X_test)
print(metrics.classification_report(y_test,
                                    predicted_values_xgb,
                                    target_names = data_merged['CLASS'].unique()))
# Out:
#                                                         precision    recall  f1-score   support
#
#                                                Питание       0.89      0.89      0.89        18
#                                 Строительные материалы       0.96      1.00      0.98        26
#                                                 Ремонт       1.00      1.00      1.00         1
#                                            Медицинский       0.00      0.00      0.00         3
#                                                 Охрана       0.99      0.99      0.99        76
#                                                    ГСМ       0.67      1.00      0.80        10
#                                          Хозяйственный       0.33      0.50      0.40         2
#                                          Электротовары       0.88      1.00      0.93         7
# Оказание услуг по проведению лабораторных исследований       0.92      0.96      0.94        46
#                                             Автомобили       1.00      0.50      0.67         4
#                                                 Одежда       0.93      0.93      0.93        15
#                                                 Мебель       0.93      1.00      0.96        13
#                                             Сантехника       0.88      1.00      0.93         7
#                                   Оценка условий труда       1.00      1.00      1.00        19
#                                           Канцелярский       1.00      0.96      0.98        25
#                                          Бытовая химия       1.00      0.67      0.80         3
#                                             Оргтехника       0.95      0.98      0.96        93
#                                     Печатная продукция       1.00      1.00      1.00         2
#                                           Автозапчасти       0.83      1.00      0.91         5
#                              Компьютерное оборудование       1.00      1.00      1.00         3
#                                            Страхование       1.00      0.89      0.94        28
#                                        Бытовая техника       1.00      1.00      1.00         1
#                                       Финансовый аудит       0.83      0.56      0.67        18
#                                           Оборудование       0.83      0.77      0.80        13
#
#                                            avg / total       0.93      0.93      0.93       438

# %% [markdown]
# ## Смотрим сколько клиентов в триггерах

# %%
from loader import Loader
import os, sys

        
file= 'tmp_select_from_triggers.csv'
query = 'select distinct inn from atb_segmen_tr_all_t'
print(query)

data=Loader(True).save_csv(query, path=file, verbose=1)   
data_triggers = pd.read_csv('tmp_select_from_triggers.csv', encoding='utf-8', delimiter=';')
data_triggers.columns = ['INN']
# Out:
# select distinct inn from atb_segmen_tr_all_t
# Connecting...
# Getting data ...
# Downloaded 10,000 lines,       0sec. passed
# Downloaded 20,000 lines,       0sec. passed
# Downloaded 30,000 lines,       0sec. passed
# Downloaded 40,000 lines,       0sec. passed
# Downloaded 50,000 lines,       0sec. passed
# Downloaded 60,000 lines,       0sec. passed
# Downloaded 70,000 lines,       0sec. passed
# Downloaded 80,000 lines,       0sec. passed
# Downloaded 90,000 lines,       0sec. passed
# Downloaded 100,000 lines,       0sec. passed
# Downloaded 110,000 lines,       0sec. passed
# Downloaded 120,000 lines,       0sec. passed
# Downloaded 130,000 lines,       0sec. passed
# Downloaded 140,000 lines,       0sec. passed
# Downloaded 150,000 lines,       0sec. passed
# Downloaded 160,000 lines,       0sec. passed
# Downloaded 170,000 lines,       0sec. passed
# Downloaded 180,000 lines,       0sec. passed
# Downloaded 190,000 lines,       0sec. passed
# Downloaded 200,000 lines,       0sec. passed
# Downloaded 210,000 lines,       0sec. passed
# Downloaded 220,000 lines,       0sec. passed
# Downloaded 230,000 lines,       0sec. passed
# Downloaded 240,000 lines,       0sec. passed
# Downloaded 250,000 lines,       0sec. passed
# Downloaded 260,000 lines,       0sec. passed
# Downloaded 270,000 lines,       1sec. passed
# Downloaded 280,000 lines,       1sec. passed
# Downloaded 290,000 lines,       1sec. passed
# Downloaded 300,000 lines,       1sec. passed
# Downloaded 310,000 lines,       1sec. passed
# Downloaded 320,000 lines,       1sec. passed
# Downloaded 330,000 lines,       1sec. passed
# Downloaded 340,000 lines,       1sec. passed
# Downloaded 350,000 lines,       1sec. passed
# Downloaded 360,000 lines,       1sec. passed
# Downloaded 370,000 lines,       1sec. passed
# Downloaded 380,000 lines,       1sec. passed
# Downloaded 390,000 lines,       1sec. passed
# Downloaded 400,000 lines,       1sec. passed
# Downloaded 410,000 lines,       1sec. passed
# Downloaded 420,000 lines,       1sec. passed
# Downloaded 430,000 lines,       1sec. passed
# Downloaded 440,000 lines,       1sec. passed
# Downloaded 450,000 lines,       1sec. passed
# Downloaded 460,000 lines,       1sec. passed
# Downloaded 470,000 lines,       1sec. passed
# Downloaded 480,000 lines,       1sec. passed
# Downloaded 490,000 lines,       1sec. passed
# Downloaded 500,000 lines,       1sec. passed
# Downloaded 510,000 lines,       1sec. passed
# Downloaded 520,000 lines,       1sec. passed
# Downloaded 530,000 lines,       1sec. passed
# Downloaded 540,000 lines,       1sec. passed
# Downloaded 550,000 lines,       1sec. passed
# Downloaded 560,000 lines,       1sec. passed
# Downloaded 570,000 lines,       1sec. passed
# Downloaded 580,000 lines,       1sec. passed
# Downloaded 590,000 lines,       1sec. passed
# Downloaded 600,000 lines,       1sec. passed
# Downloaded 610,000 lines,       1sec. passed
# Downloaded 620,000 lines,       1sec. passed
# Downloaded 630,000 lines,       1sec. passed
# Downloaded 640,000 lines,       1sec. passed
# Downloaded 650,000 lines,       1sec. passed
# Downloaded 660,000 lines,       1sec. passed
# Downloaded 670,000 lines,       1sec. passed
# Downloaded 680,000 lines,       1sec. passed
# Downloaded 690,000 lines,       1sec. passed
# Downloaded 700,000 lines,       1sec. passed
# Downloaded 710,000 lines,       1sec. passed
# Downloaded 720,000 lines,       1sec. passed
# Downloaded 730,000 lines,       1sec. passed
# Downloaded 740,000 lines,       1sec. passed
# Downloaded 750,000 lines,       1sec. passed
# Downloaded 760,000 lines,       1sec. passed
# Downloaded 770,000 lines,       1sec. passed
# Downloaded 780,000 lines,       1sec. passed
# Downloaded 790,000 lines,       1sec. passed
# Downloaded 800,000 lines,       1sec. passed
# Downloaded 810,000 lines,       1sec. passed
# Downloaded 820,000 lines,       1sec. passed
# Downloaded 830,000 lines,       2sec. passed
# Downloaded 840,000 lines,       2sec. passed
# Downloaded 850,000 lines,       2sec. passed
# Downloaded 860,000 lines,       2sec. passed
# Downloaded 870,000 lines,       2sec. passed
# Downloaded 880,000 lines,       2sec. passed
# Downloaded 890,000 lines,       2sec. passed
# Downloaded 900,000 lines,       2sec. passed
# Downloaded 910,000 lines,       2sec. passed
# Downloaded 920,000 lines,       2sec. passed
# Downloaded 930,000 lines,       2sec. passed
# Downloaded 940,000 lines,       2sec. passed
# Downloaded 950,000 lines,       2sec. passed
# Downloaded 960,000 lines,       2sec. passed
# Downloaded 970,000 lines,       2sec. passed
# Downloaded 980,000 lines,       2sec. passed
# Downloaded 990,000 lines,       2sec. passed
# Downloaded 1,000,000 lines,       2sec. passed
# Downloaded 1,010,000 lines,       2sec. passed
# Downloaded 1,020,000 lines,       2sec. passed
# Downloaded 1,030,000 lines,       2sec. passed
# Downloaded 1,040,000 lines,       2sec. passed
# Downloaded 1,050,000 lines,       2sec. passed
# Downloaded 1,060,000 lines,       2sec. passed
# Downloaded 1,070,000 lines,       2sec. passed
# Downloaded 1,080,000 lines,       2sec. passed
# Downloaded 1,090,000 lines,       2sec. passed
# Downloaded 1,100,000 lines,       2sec. passed
# Downloaded 1,110,000 lines,       2sec. passed
# Downloaded 1,120,000 lines,       2sec. passed
# Downloaded 1,130,000 lines,       2sec. passed
# Downloaded 1,140,000 lines,       2sec. passed
# Downloaded 1,150,000 lines,       2sec. passed
# Downloaded 1,160,000 lines,       2sec. passed
# Downloaded 1,170,000 lines,       2sec. passed
# Downloaded 1,180,000 lines,       2sec. passed
# Downloaded 1,190,000 lines,       2sec. passed
# Downloaded 1,200,000 lines,       2sec. passed
# Downloaded 1,210,000 lines,       2sec. passed
# Downloaded 1,220,000 lines,       2sec. passed
# Downloaded 1,230,000 lines,       2sec. passed
# Downloaded 1,240,000 lines,       2sec. passed
# Downloaded 1,250,000 lines,       2sec. passed
# Downloaded 1,260,000 lines,       2sec. passed
# Downloaded 1,270,000 lines,       2sec. passed
# Downloaded 1,280,000 lines,       2sec. passed
# Downloaded 1,290,000 lines,       2sec. passed
# Downloaded 1,300,000 lines,       2sec. passed
# Downloaded 1,310,000 lines,       2sec. passed
# Downloaded 1,320,000 lines,       2sec. passed
# Downloaded 1,330,000 lines,       3sec. passed
# Downloaded 1,340,000 lines,       3sec. passed
# Downloaded 1,350,000 lines,       3sec. passed
# Downloaded 1,360,000 lines,       3sec. passed
# Downloaded 1,370,000 lines,       3sec. passed
# Downloaded 1,380,000 lines,       3sec. passed
# Downloaded 1,390,000 lines,       3sec. passed
# Downloaded 1,400,000 lines,       3sec. passed
# Downloaded 1,410,000 lines,       3sec. passed
# Downloaded 1,420,000 lines,       3sec. passed
# Downloaded 1,430,000 lines,       3sec. passed
# Downloaded 1,440,000 lines,       3sec. passed
# Downloaded 1,450,000 lines,       3sec. passed
# Downloaded 1,460,000 lines,       3sec. passed
# Downloaded 1,470,000 lines,       3sec. passed
# Downloaded 1,480,000 lines,       3sec. passed
# Downloaded 1,490,000 lines,       3sec. passed
# Downloaded 1,500,000 lines,       3sec. passed
# Downloaded 1,510,000 lines,       3sec. passed
# Downloaded 1,520,000 lines,       3sec. passed
# Downloaded 1,530,000 lines,       3sec. passed
# Downloaded 1,540,000 lines,       3sec. passed
# Downloaded 1,550,000 lines,       3sec. passed
# Downloaded 1,560,000 lines,       3sec. passed
# Downloaded 1,570,000 lines,       3sec. passed
# Downloaded 1,580,000 lines,       3sec. passed
# Downloaded 1,590,000 lines,       3sec. passed
# Downloaded 1,600,000 lines,       3sec. passed
# Downloaded 1,610,000 lines,       3sec. passed
# Downloaded 1,620,000 lines,       3sec. passed
# Downloaded 1,630,000 lines,       3sec. passed
# Downloaded 1,640,000 lines,       3sec. passed
# Downloaded 1,650,000 lines,       3sec. passed
# Downloaded 1,660,000 lines,       3sec. passed
# Downloaded 1,670,000 lines,       3sec. passed
# Downloaded 1,680,000 lines,       3sec. passed
# Downloaded 1,690,000 lines,       3sec. passed
# Downloaded 1,700,000 lines,       3sec. passed
# Downloaded 1,710,000 lines,       3sec. passed
# Downloaded 1,720,000 lines,       3sec. passed
# Downloaded 1,730,000 lines,       3sec. passed
# Downloaded 1,740,000 lines,       3sec. passed
# Downloaded 1,750,000 lines,       3sec. passed
# Downloaded 1,760,000 lines,       3sec. passed
# Downloaded 1,770,000 lines,       3sec. passed
# Downloaded 1,780,000 lines,       3sec. passed
# Downloaded 1,790,000 lines,       3sec. passed
# Downloaded 1,800,000 lines,       3sec. passed
# Downloaded 1,810,000 lines,       3sec. passed
# Downloaded 1,820,000 lines,       3sec. passed
# Downloaded 1,830,000 lines,       3sec. passed
# Downloaded 1,840,000 lines,       3sec. passed
# Downloaded 1,850,000 lines,       4sec. passed
# Downloaded 1,860,000 lines,       4sec. passed
# Downloaded 1,870,000 lines,       4sec. passed
# Downloaded 1,880,000 lines,       4sec. passed
# Downloaded 1,890,000 lines,       4sec. passed
# Downloaded 1,900,000 lines,       4sec. passed
# Downloaded 1,910,000 lines,       4sec. passed
# Downloaded 1,920,000 lines,       4sec. passed
# Downloaded 1,930,000 lines,       4sec. passed
# Downloaded 1,940,000 lines,       4sec. passed
# Downloaded 1,950,000 lines,       4sec. passed
# Downloaded 1,960,000 lines,       4sec. passed
# Downloaded 1,970,000 lines,       4sec. passed
# Downloaded 1,980,000 lines,       4sec. passed
# Downloaded 1,990,000 lines,       4sec. passed
# Downloaded 2,000,000 lines,       4sec. passed
# Downloaded 2,010,000 lines,       4sec. passed
# Downloaded 2,020,000 lines,       4sec. passed
# Downloaded 2,030,000 lines,       4sec. passed
# Downloaded 2,040,000 lines,       4sec. passed
# Downloaded 2,050,000 lines,       4sec. passed
# Downloaded 2,060,000 lines,       4sec. passed
# Downloaded 2,070,000 lines,       4sec. passed
# Downloaded 2,080,000 lines,       4sec. passed
# Downloaded 2,090,000 lines,       4sec. passed
# Downloaded 2,100,000 lines,       4sec. passed
# Downloaded 2,110,000 lines,       4sec. passed
# Downloaded 2,120,000 lines,       4sec. passed
# Downloaded 2,130,000 lines,       4sec. passed
# Downloaded 2,140,000 lines,       4sec. passed
# Downloaded 2,150,000 lines,       4sec. passed
# Downloaded 2,160,000 lines,       4sec. passed
# Downloaded 2,170,000 lines,       4sec. passed
# Downloaded 2,180,000 lines,       4sec. passed
# Downloaded 2,190,000 lines,       4sec. passed
# Downloaded 2,200,000 lines,       4sec. passed
# Downloaded 2,210,000 lines,       4sec. passed
# Downloaded 2,220,000 lines,       4sec. passed
# Downloaded 2,230,000 lines,       4sec. passed
# Downloaded 2,240,000 lines,       5sec. passed
# Downloaded 2,250,000 lines,       5sec. passed
# Downloaded 2,260,000 lines,       5sec. passed
# Downloaded 2,270,000 lines,       5sec. passed
# Downloaded 2,280,000 lines,       5sec. passed
# Downloaded 2,290,000 lines,       5sec. passed
# Downloaded 2,300,000 lines,       5sec. passed
# Downloaded 2,310,000 lines,       5sec. passed
# Downloaded 2,320,000 lines,       5sec. passed
# Downloaded 2,330,000 lines,       5sec. passed
# Downloaded 2,340,000 lines,       5sec. passed
# Downloaded 2,350,000 lines,       5sec. passed
# Downloaded 2,360,000 lines,       5sec. passed
# Downloaded 2,370,000 lines,       5sec. passed
# Downloaded 2,380,000 lines,       5sec. passed
# Downloaded 2,390,000 lines,       5sec. passed
# Downloaded 2,400,000 lines,       5sec. passed
# Downloaded 2,410,000 lines,       5sec. passed
# Downloaded 2,420,000 lines,       5sec. passed
# Downloaded 2,430,000 lines,       5sec. passed
# Downloaded 2,440,000 lines,       5sec. passed
# Downloaded 2,450,000 lines,       5sec. passed
# Downloaded 2,460,000 lines,       5sec. passed
# Downloaded 2,470,000 lines,       5sec. passed
# Downloaded 2,480,000 lines,       5sec. passed
# Downloaded 2,490,000 lines,       5sec. passed
# Downloaded 2,500,000 lines,       5sec. passed
# Downloaded 2,510,000 lines,       5sec. passed
# Downloaded 2,520,000 lines,       5sec. passed
# Downloaded 2,530,000 lines,       5sec. passed
# Downloaded 2,540,000 lines,       5sec. passed
# Downloaded 2,550,000 lines,       5sec. passed
# Downloaded 2,560,000 lines,       5sec. passed
# Downloaded 2,570,000 lines,       5sec. passed
# Downloaded 2,580,000 lines,       5sec. passed
# Downloaded 2,590,000 lines,       5sec. passed
# Downloaded 2,600,000 lines,       5sec. passed
# Downloaded 2,610,000 lines,       5sec. passed
# Downloaded 2,620,000 lines,       5sec. passed
# Downloaded 2,630,000 lines,       5sec. passed
# Downloaded 2,640,000 lines,       5sec. passed
# Downloaded 2,650,000 lines,       5sec. passed
# Downloaded 2,660,000 lines,       5sec. passed
# Downloaded 2,670,000 lines,       5sec. passed
# Downloaded 2,680,000 lines,       5sec. passed
# Downloaded 2,690,000 lines,       5sec. passed
# Downloaded 2,700,000 lines,       5sec. passed
# Downloaded 2,710,000 lines,       5sec. passed
# Downloaded 2,720,000 lines,       5sec. passed
# Downloaded 2,730,000 lines,       5sec. passed
# Downloaded 2,740,000 lines,       5sec. passed
# Downloaded 2,750,000 lines,       5sec. passed
# Downloaded 2,760,000 lines,       5sec. passed
# Downloaded 2,770,000 lines,       6sec. passed
# Downloaded 2,780,000 lines,       6sec. passed
# Downloaded 2,790,000 lines,       6sec. passed
# Downloaded 2,800,000 lines,       6sec. passed
# Downloaded 2,810,000 lines,       6sec. passed
# Downloaded 2,820,000 lines,       6sec. passed
# Downloaded 2,830,000 lines,       6sec. passed
# Downloaded 2,840,000 lines,       6sec. passed
# Downloaded 2,850,000 lines,       6sec. passed
# Downloaded 2,860,000 lines,       6sec. passed
# Downloaded 2,870,000 lines,       6sec. passed
# Downloaded 2,880,000 lines,       6sec. passed
# Downloaded 2,890,000 lines,       6sec. passed
# Downloaded 2,900,000 lines,       6sec. passed
# Downloaded 2,910,000 lines,       6sec. passed
# Downloaded 2,920,000 lines,       6sec. passed
# Downloaded 2,930,000 lines,       6sec. passed
# Downloaded 2,940,000 lines,       6sec. passed

# %%
len(pd.merge(data_triggers,data,on = 'INN')['INN'].drop_duplicates())
# Out:
# 2163

# %%
len(data['INN'].drop_duplicates())
# Out:
# 2167
